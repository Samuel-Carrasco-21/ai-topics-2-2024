# %%
import requests
from bs4 import BeautifulSoup

bts_id = 47923


def extract_lyrics_links(artist_url: str) -> list[str]:
    response = requests.get(url=artist_url)
    print(f"Response from artist page: {response.status_code}")
    soup = BeautifulSoup(response.text, "html.parser")
    links_ul = soup.find("ul", class_="listado-letras")
    links = [a["href"] for a in links_ul.find_all("a")]
    return links

def extract_song_lyric(song_url: str) -> str:
    response = requests.get(url=song_url)
    response.encoding = "utf-8"
    print(f"Response from lyrics page: {response.status_code}")
    soup = BeautifulSoup(response.text, "html.parser")
    song_title = soup.find("h1").get_text()
    print(f"Title: {song_title}")
    header = soup.find("h2", string="LETRA")
    if header is None:
        header = soup.find("h2", string="LETRA EN ESPAÑOL")
        
    if header is None:
        return ""

    paragraphs = []

    for p in header.find_all_next("p"):
        if p.find_parent("div") is None:
            continue
        if p.find_parent("div").get("id") == "letra":
            paragraphs.append(p.get_text(separator="\n"))

    lyrics = "\n".join(p for p in paragraphs)
    return f"Título: {song_title} \n\n {lyrics}"

def extract_artist_lyrics(artist: str, artist_id: int):
    lyrics_url = f"https://www.musica.com/letras.asp?letras={artist_id}&orden=alf"
    links = extract_lyrics_links(lyrics_url)
    print(f"found {len(links)} songs")
    artist_header = f"{artist}\n===\n"
    lyrics = []
    for link in links:
        print(f"extracting song from: {link}")
        lyrics.append(extract_song_lyric(link))
    lyrics_str = "\n\n===\n\n".join(lyrics)
    artist_str = artist_header + lyrics_str
    with open(f"{artist_id}_{artist}.txt", "w", encoding="utf-8") as file:
        file.write(artist_str)
    return artist_str

# %%
# extract_artist_lyrics("Kjarkas", kjarkas_id)
extract_artist_lyrics("BTS", bts_id)
# Out:
# Response from artist page: 200
# found 314 songs
# extracting song from: https://www.musica.com/letras.asp?letra=2376498
# Response from lyrics page: 200
# Title: 離れないで (歌詞)
# extracting song from: https://www.musica.com/letras.asp?letra=2291365
# Response from lyrics page: 200
# Title: 방탄소년단 Save Me
# extracting song from: https://www.musica.com/letras.asp?letra=2354039
# Response from lyrics page: 200
# Title: 방탄소년단 Save Me en español
# extracting song from: https://www.musica.com/letras.asp?letra=2286247
# Response from lyrics page: 200
# Title: 봄날 (Spring Day) Korean
# extracting song from: https://www.musica.com/letras.asp?letra=2506678
# Response from lyrics page: 200
# Title: 00:00 (Zero O’Clock)
# extracting song from: https://www.musica.com/letras.asp?letra=2506694
# Response from lyrics page: 200
# Title: 00:00 (Zero O’Clock) en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383772
# Response from lyrics page: 200
# Title: 134340 en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383770
# Response from lyrics page: 200
# Title: 134340 en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2383774
# Response from lyrics page: 200
# Title: 134340 (Romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2353051
# Response from lyrics page: 200
# Title: 21st Century Girl
# extracting song from: https://www.musica.com/letras.asp?letra=2353432
# Response from lyrics page: 200
# Title: 21st Century Girl en español
# extracting song from: https://www.musica.com/letras.asp?letra=2358092
# Response from lyrics page: 200
# Title: 21st Century Girl en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2466919
# Response from lyrics page: 200
# Title: A Brand New Day
# extracting song from: https://www.musica.com/letras.asp?letra=2466920
# Response from lyrics page: 200
# Title: A Brand New Day Romanizada
# extracting song from: https://www.musica.com/letras.asp?letra=2466921
# Response from lyrics page: 200
# Title: A Brand New Day Romanizada en español
# extracting song from: https://www.musica.com/letras.asp?letra=2175900
# Response from lyrics page: 200
# Title: A Typical Idol’s Christmas
# extracting song from: https://www.musica.com/letras.asp?letra=2175902
# Response from lyrics page: 200
# Title: A Typical Idol's Christmas en español
# extracting song from: https://www.musica.com/letras.asp?letra=2175903
# Response from lyrics page: 200
# Title: A Typical Idol's Christmas en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2536745
# Response from lyrics page: 200
# Title: Abyss (Jin)
# extracting song from: https://www.musica.com/letras.asp?letra=2536744
# Response from lyrics page: 200
# Title: Abyss (Jin) en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174444
# Response from lyrics page: 200
# Title: Adult Child
# extracting song from: https://www.musica.com/letras.asp?letra=2174646
# Response from lyrics page: 200
# Title: Adult Child en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174584
# Response from lyrics page: 200
# Title: Adult Child en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2383736
# Response from lyrics page: 200
# Title: Airplane Pt. 2 en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383734
# Response from lyrics page: 200
# Title: Airplane Pt. 2 en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2383738
# Response from lyrics page: 200
# Title: Airplane Pt. 2 (Romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2469804
# Response from lyrics page: 200
# Title: All Night Romanizada
# extracting song from: https://www.musica.com/letras.asp?letra=2403609
# Response from lyrics page: 200
# Title: Anpanman
# extracting song from: https://www.musica.com/letras.asp?letra=2383720
# Response from lyrics page: 200
# Title: Anpanman en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383727
# Response from lyrics page: 200
# Title: Anpanman en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2353969
# Response from lyrics page: 200
# Title: Autumm Leaves en español
# extracting song from: https://www.musica.com/letras.asp?letra=2353970
# Response from lyrics page: 200
# Title: Autumm Leaves en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2291902
# Response from lyrics page: 200
# Title: Autumn leaves
# extracting song from: https://www.musica.com/letras.asp?letra=2577895
# Response from lyrics page: 200
# Title: Bad Decisions
# extracting song from: https://www.musica.com/letras.asp?letra=2350472
# Response from lyrics page: 200
# Title: Best Of Me
# extracting song from: https://www.musica.com/letras.asp?letra=2350471
# Response from lyrics page: 200
# Title: Best Of Me en español
# extracting song from: https://www.musica.com/letras.asp?letra=2355491
# Response from lyrics page: 200
# Title: Best Of Me en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2501539
# Response from lyrics page: 200
# Title: Black Swan
# extracting song from: https://www.musica.com/letras.asp?letra=2309410
# Response from lyrics page: 200
# Title: Blood Sweat & Tears en español
# extracting song from: https://www.musica.com/letras.asp?letra=2361540
# Response from lyrics page: 200
# Title: Blood Sweat & Tears en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2265152
# Response from lyrics page: 200
# Title: Blood, Sweat And Tears
# extracting song from: https://www.musica.com/letras.asp?letra=2534897
# Response from lyrics page: 200
# Title: Blue & Grey
# extracting song from: https://www.musica.com/letras.asp?letra=2157049
# Response from lyrics page: 200
# Title: Born Singer
# extracting song from: https://www.musica.com/letras.asp?letra=2175889
# Response from lyrics page: 200
# Title: Born Singer en español
# extracting song from: https://www.musica.com/letras.asp?letra=2175888
# Response from lyrics page: 200
# Title: Born Singer en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2174230
# Response from lyrics page: 200
# Title: Boy In Luv en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174597
# Response from lyrics page: 200
# Title: Boy In Luv en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2449134
# Response from lyrics page: 200
# Title: Boy With Luv Romanizado
# extracting song from: https://www.musica.com/letras.asp?letra=2449136
# Response from lyrics page: 200
# Title: Boy With Luv Romanizado en español
# extracting song from: https://www.musica.com/letras.asp?letra=2358095
# Response from lyrics page: 200
# Title: Boys In Luv en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2402508
# Response from lyrics page: 200
# Title: BTS (방탄소년단) Teaser
# extracting song from: https://www.musica.com/letras.asp?letra=2550032
# Response from lyrics page: 200
# Title: Butter
# extracting song from: https://www.musica.com/letras.asp?letra=2556786
# Response from lyrics page: 200
# Title: Butter
# extracting song from: https://www.musica.com/letras.asp?letra=2236587
# Response from lyrics page: 200
# Title: Butterfly
# extracting song from: https://www.musica.com/letras.asp?letra=2236586
# Response from lyrics page: 200
# Title: Butterfly en español
# extracting song from: https://www.musica.com/letras.asp?letra=2355485
# Response from lyrics page: 200
# Title: Butterfly en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2152231
# Response from lyrics page: 200
# Title: Coffee
# extracting song from: https://www.musica.com/letras.asp?letra=2174572
# Response from lyrics page: 200
# Title: Coffee en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174647
# Response from lyrics page: 200
# Title: Coffee en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2358413
# Response from lyrics page: 200
# Title: Come Back Home
# extracting song from: https://www.musica.com/letras.asp?letra=2358415
# Response from lyrics page: 200
# Title: Come Back Home en español
# extracting song from: https://www.musica.com/letras.asp?letra=2358414
# Response from lyrics page: 200
# Title: Come Back Home en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2261209
# Response from lyrics page: 200
# Title: Converse High
# extracting song from: https://www.musica.com/letras.asp?letra=2357808
# Response from lyrics page: 200
# Title: Converse High en español
# extracting song from: https://www.musica.com/letras.asp?letra=2357809
# Response from lyrics page: 200
# Title: Converse High en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2365441
# Response from lyrics page: 200
# Title: Crystal Snow
# extracting song from: https://www.musica.com/letras.asp?letra=2174709
# Response from lyrics page: 200
# Title: Cypher Pt. 1 en español
# extracting song from: https://www.musica.com/letras.asp?letra=2152191
# Response from lyrics page: 200
# Title: Cypher Pt.1
# extracting song from: https://www.musica.com/letras.asp?letra=2174648
# Response from lyrics page: 200
# Title: Cypher Pt.1 en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2174442
# Response from lyrics page: 200
# Title: Cypher PT.2 : Triptych en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174443
# Response from lyrics page: 200
# Title: Cypher Pt.2: Triptych
# extracting song from: https://www.musica.com/letras.asp?letra=2174590
# Response from lyrics page: 200
# Title: Cypher Pt.2:Triptych en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2361541
# Response from lyrics page: 200
# Title: Cypher Pt.3
# extracting song from: https://www.musica.com/letras.asp?letra=2361543
# Response from lyrics page: 200
# Title: Cypher Pt.3 en español
# extracting song from: https://www.musica.com/letras.asp?letra=2361542
# Response from lyrics page: 200
# Title: Cypher Pt.3 en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2353038
# Response from lyrics page: 200
# Title: Cypher Pt.4
# extracting song from: https://www.musica.com/letras.asp?letra=2353039
# Response from lyrics page: 200
# Title: Cypher Pt.4 en español
# extracting song from: https://www.musica.com/letras.asp?letra=2353045
# Response from lyrics page: 200
# Title: Cypher Pt.4 en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2192793
# Response from lyrics page: 200
# Title: Danger
# extracting song from: https://www.musica.com/letras.asp?letra=2353696
# Response from lyrics page: 200
# Title: Danger en español
# extracting song from: https://www.musica.com/letras.asp?letra=2353700
# Response from lyrics page: 200
# Title: Danger en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2439814
# Response from lyrics page: 200
# Title: Dimple (romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2449010
# Response from lyrics page: 200
# Title: Dionysus
# extracting song from: https://www.musica.com/letras.asp?letra=2332735
# Response from lyrics page: 200
# Title: Dna
# extracting song from: https://www.musica.com/letras.asp?letra=2332737
# Response from lyrics page: 200
# Title: Dna en español
# extracting song from: https://www.musica.com/letras.asp?letra=2332736
# Response from lyrics page: 200
# Title: Dna en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2376520
# Response from lyrics page: 200
# Title: Don't Leave Me
# extracting song from: https://www.musica.com/letras.asp?letra=2376521
# Response from lyrics page: 200
# Title: Don't Leave Me en español
# extracting song from: https://www.musica.com/letras.asp?letra=2353435
# Response from lyrics page: 200
# Title: Dope
# extracting song from: https://www.musica.com/letras.asp?letra=2235224
# Response from lyrics page: 200
# Title: Dope en español
# extracting song from: https://www.musica.com/letras.asp?letra=2462338
# Response from lyrics page: 200
# Title: Dream Glow
# extracting song from: https://www.musica.com/letras.asp?letra=2464327
# Response from lyrics page: 200
# Title: Dream Glow en español
# extracting song from: https://www.musica.com/letras.asp?letra=2462339
# Response from lyrics page: 200
# Title: Dream Glow Romanizado
# extracting song from: https://www.musica.com/letras.asp?letra=2522338
# Response from lyrics page: 200
# Title: Dynamite
# extracting song from: https://www.musica.com/letras.asp?letra=2522424
# Response from lyrics page: 200
# Title: Dynamite en español
# extracting song from: https://www.musica.com/letras.asp?letra=2469970
# Response from lyrics page: 200
# Title: Ending Scene (Romanization)
# extracting song from: https://www.musica.com/letras.asp?letra=2398720
# Response from lyrics page: 200
# Title: Epiphany
# extracting song from: https://www.musica.com/letras.asp?letra=2398723
# Response from lyrics page: 200
# Title: Epiphany en español
# extracting song from: https://www.musica.com/letras.asp?letra=2398722
# Response from lyrics page: 200
# Title: Epiphany en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2402978
# Response from lyrics page: 200
# Title: Euphoria
# extracting song from: https://www.musica.com/letras.asp?letra=2438092
# Response from lyrics page: 200
# Title: Euphoria en español
# extracting song from: https://www.musica.com/letras.asp?letra=2358153
# Response from lyrics page: 200
# Title: Even If I Die, It's You - V & Jin ( Hwarang OST )
# extracting song from: https://www.musica.com/letras.asp?letra=2358155
# Response from lyrics page: 200
# Title: Even If I Die, It's You - V & Jin ( Hwarang OST ) ( en inglés)
# extracting song from: https://www.musica.com/letras.asp?letra=2358211
# Response from lyrics page: 200
# Title: Even If I Die, It's You - V & Jin en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383745
# Response from lyrics page: 200
# Title: Fake Love
# extracting song from: https://www.musica.com/letras.asp?letra=2383746
# Response from lyrics page: 200
# Title: Fake Love en español
# extracting song from: https://www.musica.com/letras.asp?letra=2384028
# Response from lyrics page: 200
# Title: Fake Love en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2546471
# Response from lyrics page: 200
# Title: Film out
# extracting song from: https://www.musica.com/letras.asp?letra=2546308
# Response from lyrics page: 200
# Title: Film Out en español
# extracting song from: https://www.musica.com/letras.asp?letra=2506679
# Response from lyrics page: 200
# Title: Filter
# extracting song from: https://www.musica.com/letras.asp?letra=2506691
# Response from lyrics page: 200
# Title: Filter en español
# extracting song from: https://www.musica.com/letras.asp?letra=2246063
# Response from lyrics page: 200
# Title: Fire en español
# extracting song from: https://www.musica.com/letras.asp?letra=2254431
# Response from lyrics page: 200
# Title: Fire (Versión Japonesa)
# extracting song from: https://www.musica.com/letras.asp?letra=2353050
# Response from lyrics page: 200
# Title: Go Go
# extracting song from: https://www.musica.com/letras.asp?letra=2353360
# Response from lyrics page: 200
# Title: Go Go en español
# extracting song from: https://www.musica.com/letras.asp?letra=2353363
# Response from lyrics page: 200
# Title: Go Go en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2174445
# Response from lyrics page: 200
# Title: Graduation Song
# extracting song from: https://www.musica.com/letras.asp?letra=2174723
# Response from lyrics page: 200
# Title: Graduation Song en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174649
# Response from lyrics page: 200
# Title: Graduation Song en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2469803
# Response from lyrics page: 200
# Title: Heartbeat (romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2402958
# Response from lyrics page: 200
# Title: Her en español
# extracting song from: https://www.musica.com/letras.asp?letra=2355514
# Response from lyrics page: 200
# Title: Hold me tight en español
# extracting song from: https://www.musica.com/letras.asp?letra=2449011
# Response from lyrics page: 200
# Title: Home
# extracting song from: https://www.musica.com/letras.asp?letra=2143198
# Response from lyrics page: 200
# Title: I like it
# extracting song from: https://www.musica.com/letras.asp?letra=2153674
# Response from lyrics page: 200
# Title: I like it en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174650
# Response from lyrics page: 200
# Title: I like it en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2265153
# Response from lyrics page: 200
# Title: I Need U
# extracting song from: https://www.musica.com/letras.asp?letra=2297244
# Response from lyrics page: 200
# Title: I Need U en español
# extracting song from: https://www.musica.com/letras.asp?letra=2218476
# Response from lyrics page: 200
# Title: I need you en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2402959
# Response from lyrics page: 200
# Title: I’m Fine en español
# extracting song from: https://www.musica.com/letras.asp?letra=2402961
# Response from lyrics page: 200
# Title: I’m Fine (가사해석)
# extracting song from: https://www.musica.com/letras.asp?letra=2402960
# Response from lyrics page: 200
# Title: Idol en español
# extracting song from: https://www.musica.com/letras.asp?letra=2404129
# Response from lyrics page: 200
# Title: Idol
# extracting song from: https://www.musica.com/letras.asp?letra=2404030
# Response from lyrics page: 200
# Title: Idol (Romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2152230
# Response from lyrics page: 200
# Title: If I Ruled The World
# extracting song from: https://www.musica.com/letras.asp?letra=2174571
# Response from lyrics page: 200
# Title: If I Ruled The World en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174651
# Response from lyrics page: 200
# Title: If I Ruled The World en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2350406
# Response from lyrics page: 200
# Title: Illegal
# extracting song from: https://www.musica.com/letras.asp?letra=2350418
# Response from lyrics page: 200
# Title: Illegal en español
# extracting song from: https://www.musica.com/letras.asp?letra=2353693
# Response from lyrics page: 200
# Title: Illegal en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2403038
# Response from lyrics page: 200
# Title: I'm Fine en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2404025
# Response from lyrics page: 200
# Title: I'm Fine (Romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2506680
# Response from lyrics page: 200
# Title: Inner Child
# extracting song from: https://www.musica.com/letras.asp?letra=2506693
# Response from lyrics page: 200
# Title: Inner Child en español
# extracting song from: https://www.musica.com/letras.asp?letra=2500635
# Response from lyrics page: 200
# Title: Interlude Shadow
# extracting song from: https://www.musica.com/letras.asp?letra=2500636
# Response from lyrics page: 200
# Title: Interlude Shadow en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174483
# Response from lyrics page: 200
# Title: Intro: O!RUL8
# extracting song from: https://www.musica.com/letras.asp?letra=2174581
# Response from lyrics page: 200
# Title: Intro: O!RUL8 en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174653
# Response from lyrics page: 200
# Title: Intro: O!RUL8 en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2506681
# Response from lyrics page: 200
# Title: Intro: Persona
# extracting song from: https://www.musica.com/letras.asp?letra=2382347
# Response from lyrics page: 200
# Title: Intro: Singularity (Love Yourself Album) en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174487
# Response from lyrics page: 200
# Title: Intro: Skool Luv affair
# extracting song from: https://www.musica.com/letras.asp?letra=2174596
# Response from lyrics page: 200
# Title: Intro: Skool Luv affair en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2175374
# Response from lyrics page: 200
# Title: Intro:Skool Luv Affair en español
# extracting song from: https://www.musica.com/letras.asp?letra=2524296
# Response from lyrics page: 200
# Title: IONIQ: I’m On It
# extracting song from: https://www.musica.com/letras.asp?letra=2524297
# Response from lyrics page: 200
# Title: IONIQ: I’m On It en español
# extracting song from: https://www.musica.com/letras.asp?letra=2449012
# Response from lyrics page: 200
# Title: Jamais Vu
# extracting song from: https://www.musica.com/letras.asp?letra=2234588
# Response from lyrics page: 200
# Title: J-Hope 1verse
# extracting song from: https://www.musica.com/letras.asp?letra=2354355
# Response from lyrics page: 200
# Title: J-Hope 1verse en español
# extracting song from: https://www.musica.com/letras.asp?letra=2354356
# Response from lyrics page: 200
# Title: J-Hope 1verse en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2174494
# Response from lyrics page: 200
# Title: Jump
# extracting song from: https://www.musica.com/letras.asp?letra=2175383
# Response from lyrics page: 200
# Title: Jump en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174587
# Response from lyrics page: 200
# Title: Jump en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2174489
# Response from lyrics page: 200
# Title: Just One Day
# extracting song from: https://www.musica.com/letras.asp?letra=2175379
# Response from lyrics page: 200
# Title: Just One Day en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174593
# Response from lyrics page: 200
# Title: Just One Day en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2388450
# Response from lyrics page: 200
# Title: Let go en español
# extracting song from: https://www.musica.com/letras.asp?letra=2432457
# Response from lyrics page: 200
# Title: Let Go (romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2318261
# Response from lyrics page: 200
# Title: Lie - Jimin en español
# extracting song from: https://www.musica.com/letras.asp?letra=2534820
# Response from lyrics page: 200
# Title: Life Goes On
# extracting song from: https://www.musica.com/letras.asp?letra=2535268
# Response from lyrics page: 200
# Title: Life Goes On en español
# extracting song from: https://www.musica.com/letras.asp?letra=2468212
# Response from lyrics page: 200
# Title: Lights
# extracting song from: https://www.musica.com/letras.asp?letra=2471763
# Response from lyrics page: 200
# Title: Lights en español
# extracting song from: https://www.musica.com/letras.asp?letra=2192794
# Response from lyrics page: 200
# Title: Look Here
# extracting song from: https://www.musica.com/letras.asp?letra=2506682
# Response from lyrics page: 200
# Title: Louder than bombs
# extracting song from: https://www.musica.com/letras.asp?letra=2506692
# Response from lyrics page: 200
# Title: Louder than bombs en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383753
# Response from lyrics page: 200
# Title: Love Maze en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383754
# Response from lyrics page: 200
# Title: Love Maze en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2383756
# Response from lyrics page: 200
# Title: Love Maze (Romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2383744
# Response from lyrics page: 200
# Title: Magic Shop en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383749
# Response from lyrics page: 200
# Title: Magic Shop en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2449013
# Response from lyrics page: 200
# Title: Make It Right
# extracting song from: https://www.musica.com/letras.asp?letra=2487127
# Response from lyrics page: 200
# Title: Make It Right Remix Romanizado
# extracting song from: https://www.musica.com/letras.asp?letra=2487126
# Response from lyrics page: 200
# Title: Make It Right Remix Romanizado en español
# extracting song from: https://www.musica.com/letras.asp?letra=2353047
# Response from lyrics page: 200
# Title: MIC Drop
# extracting song from: https://www.musica.com/letras.asp?letra=2353048
# Response from lyrics page: 200
# Title: MIC Drop en español
# extracting song from: https://www.musica.com/letras.asp?letra=2353067
# Response from lyrics page: 200
# Title: MIC Drop en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2506683
# Response from lyrics page: 200
# Title: Moon
# extracting song from: https://www.musica.com/letras.asp?letra=2506752
# Response from lyrics page: 200
# Title: Moon en español
# extracting song from: https://www.musica.com/letras.asp?letra=2229916
# Response from lyrics page: 200
# Title: Move
# extracting song from: https://www.musica.com/letras.asp?letra=2557777
# Response from lyrics page: 200
# Title: My Universe
# extracting song from: https://www.musica.com/letras.asp?letra=2561253
# Response from lyrics page: 200
# Title: My Universe Galantis Remix
# extracting song from: https://www.musica.com/letras.asp?letra=2560208
# Response from lyrics page: 200
# Title: My Universe SUGA's Remix
# extracting song from: https://www.musica.com/letras.asp?letra=2558520
# Response from lyrics page: 200
# Title: My Universe En Español en español
# extracting song from: https://www.musica.com/letras.asp?letra=2152225
# Response from lyrics page: 200
# Title: N.o
# extracting song from: https://www.musica.com/letras.asp?letra=2156584
# Response from lyrics page: 200
# Title: N.o en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174654
# Response from lyrics page: 200
# Title: N.o en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2143196
# Response from lyrics page: 200
# Title: No more dream
# extracting song from: https://www.musica.com/letras.asp?letra=2143197
# Response from lyrics page: 200
# Title: No more dream en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174655
# Response from lyrics page: 200
# Title: No more dream en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2284604
# Response from lyrics page: 200
# Title: Not today
# extracting song from: https://www.musica.com/letras.asp?letra=2354143
# Response from lyrics page: 200
# Title: Not Today ( in inglés )
# extracting song from: https://www.musica.com/letras.asp?letra=2354142
# Response from lyrics page: 200
# Title: Not today en español
# extracting song from: https://www.musica.com/letras.asp?letra=2506684
# Response from lyrics page: 200
# Title: On
# extracting song from: https://www.musica.com/letras.asp?letra=2506696
# Response from lyrics page: 200
# Title: On en español
# extracting song from: https://www.musica.com/letras.asp?letra=2506685
# Response from lyrics page: 200
# Title: ON Remix
# extracting song from: https://www.musica.com/letras.asp?letra=2174616
# Response from lyrics page: 200
# Title: Outro: Circle Room Cypher
# extracting song from: https://www.musica.com/letras.asp?letra=2174816
# Response from lyrics page: 200
# Title: Outro: Circle Room Cypher en español
# extracting song from: https://www.musica.com/letras.asp?letra=2391143
# Response from lyrics page: 200
# Title: Outro: House Of Cards
# extracting song from: https://www.musica.com/letras.asp?letra=2152192
# Response from lyrics page: 200
# Title: Outro: Luv In Skool
# extracting song from: https://www.musica.com/letras.asp?letra=2174579
# Response from lyrics page: 200
# Title: Outro: Luv In Skool en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174599
# Response from lyrics page: 200
# Title: Outro: Luv In Skool en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2174495
# Response from lyrics page: 200
# Title: Outro: Propose
# extracting song from: https://www.musica.com/letras.asp?letra=2175384
# Response from lyrics page: 200
# Title: Outro: Propose en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174586
# Response from lyrics page: 200
# Title: Outro: Propose en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2383707
# Response from lyrics page: 200
# Title: Outro: Tear en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383709
# Response from lyrics page: 200
# Title: Outro: Tear en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2383706
# Response from lyrics page: 200
# Title: Outro: Tear (Legendado)
# extracting song from: https://www.musica.com/letras.asp?letra=2357666
# Response from lyrics page: 200
# Title: Outro: Wings
# extracting song from: https://www.musica.com/letras.asp?letra=2357669
# Response from lyrics page: 200
# Title: Outro: Wings en español
# extracting song from: https://www.musica.com/letras.asp?letra=2357668
# Response from lyrics page: 200
# Title: Outro: Wings en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2553382
# Response from lyrics page: 200
# Title: Permission to Dance
# extracting song from: https://www.musica.com/letras.asp?letra=2446694
# Response from lyrics page: 200
# Title: Persona
# extracting song from: https://www.musica.com/letras.asp?letra=2446695
# Response from lyrics page: 200
# Title: PERSONA (romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2446696
# Response from lyrics page: 200
# Title: PERSONA (romanizado) en español
# extracting song from: https://www.musica.com/letras.asp?letra=2392846
# Response from lyrics page: 200
# Title: Pied Piper
# extracting song from: https://www.musica.com/letras.asp?letra=2506686
# Response from lyrics page: 200
# Title: Respect
# extracting song from: https://www.musica.com/letras.asp?letra=2506754
# Response from lyrics page: 200
# Title: Respect en español
# extracting song from: https://www.musica.com/letras.asp?letra=2236222
# Response from lyrics page: 200
# Title: Run
# extracting song from: https://www.musica.com/letras.asp?letra=2260856
# Response from lyrics page: 200
# Title: Run en español
# extracting song from: https://www.musica.com/letras.asp?letra=2260906
# Response from lyrics page: 200
# Title: Run en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2174486
# Response from lyrics page: 200
# Title: Satoori Rap
# extracting song from: https://www.musica.com/letras.asp?letra=2174578
# Response from lyrics page: 200
# Title: Satoori Rap en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174600
# Response from lyrics page: 200
# Title: Satoori Rap en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2297368
# Response from lyrics page: 200
# Title: Save Me
# extracting song from: https://www.musica.com/letras.asp?letra=2354040
# Response from lyrics page: 200
# Title: Save Me (방탄소년단) en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2436831
# Response from lyrics page: 200
# Title: Scenery -V (Taehyung) en español
# extracting song from: https://www.musica.com/letras.asp?letra=2145007
# Response from lyrics page: 200
# Title: School Of Tears
# extracting song from: https://www.musica.com/letras.asp?letra=2153673
# Response from lyrics page: 200
# Title: School Of Tears en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174656
# Response from lyrics page: 200
# Title: School Of Tears en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2411444
# Response from lyrics page: 200
# Title: Seesaw x I Need U (Remix)
# extracting song from: https://www.musica.com/letras.asp?letra=2329462
# Response from lyrics page: 200
# Title: Serendipity
# extracting song from: https://www.musica.com/letras.asp?letra=2329463
# Response from lyrics page: 200
# Title: Serendipity en español
# extracting song from: https://www.musica.com/letras.asp?letra=2254433
# Response from lyrics page: 200
# Title: Silver Spoon
# extracting song from: https://www.musica.com/letras.asp?letra=2254434
# Response from lyrics page: 200
# Title: Silver Spoon en español
# extracting song from: https://www.musica.com/letras.asp?letra=2254435
# Response from lyrics page: 200
# Title: Silver Spoon en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2382349
# Response from lyrics page: 200
# Title: Singularity (Love Yourself Album)
# extracting song from: https://www.musica.com/letras.asp?letra=2382348
# Response from lyrics page: 200
# Title: Singularity (Love Yourself Album) en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2382350
# Response from lyrics page: 200
# Title: Singularity (Love Yourself Album) (Romanized)
# extracting song from: https://www.musica.com/letras.asp?letra=2534898
# Response from lyrics page: 200
# Title: Skit
# extracting song from: https://www.musica.com/letras.asp?letra=2174617
# Response from lyrics page: 200
# Title: Skit: Are You Happy Now?
# extracting song from: https://www.musica.com/letras.asp?letra=2175372
# Response from lyrics page: 200
# Title: Skit: Are You Happy Now? en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174738
# Response from lyrics page: 200
# Title: Skit: Circle Room Talk en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174614
# Response from lyrics page: 200
# Title: Skit: Circle Room Talk en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2383716
# Response from lyrics page: 200
# Title: So What en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383717
# Response from lyrics page: 200
# Title: So What en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2174493
# Response from lyrics page: 200
# Title: Spine Breaker
# extracting song from: https://www.musica.com/letras.asp?letra=2175382
# Response from lyrics page: 200
# Title: Spine Breaker en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174588
# Response from lyrics page: 200
# Title: Spine Breaker en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2286246
# Response from lyrics page: 200
# Title: Spring Day en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2286245
# Response from lyrics page: 200
# Title: Spring Day (romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2286250
# Response from lyrics page: 200
# Title: Spring Day (romanizado) en español
# extracting song from: https://www.musica.com/letras.asp?letra=2534901
# Response from lyrics page: 200
# Title: Stay
# extracting song from: https://www.musica.com/letras.asp?letra=2520060
# Response from lyrics page: 200
# Title: Stay gold
# extracting song from: https://www.musica.com/letras.asp?letra=2520061
# Response from lyrics page: 200
# Title: Stay gold  En Español en español
# extracting song from: https://www.musica.com/letras.asp?letra=2313515
# Response from lyrics page: 200
# Title: Stigma
# extracting song from: https://www.musica.com/letras.asp?letra=2515810
# Response from lyrics page: 200
# Title: Still With You (Jungkook)
# extracting song from: https://www.musica.com/letras.asp?letra=2594440
# Response from lyrics page: 200
# Title: Take Two (Romanizada)
# extracting song from: https://www.musica.com/letras.asp?letra=2534899
# Response from lyrics page: 200
# Title: Telepathy
# extracting song from: https://www.musica.com/letras.asp?letra=2152188
# Response from lyrics page: 200
# Title: The Rise Of Bangtan
# extracting song from: https://www.musica.com/letras.asp?letra=2174576
# Response from lyrics page: 200
# Title: The Rise Of Bangtan en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174657
# Response from lyrics page: 200
# Title: The Rise Of Bangtan en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2383747
# Response from lyrics page: 200
# Title: The Truth Untold
# extracting song from: https://www.musica.com/letras.asp?letra=2383748
# Response from lyrics page: 200
# Title: The Truth Untold en español
# extracting song from: https://www.musica.com/letras.asp?letra=2383764
# Response from lyrics page: 200
# Title: The Truth Untold en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2404755
# Response from lyrics page: 200
# Title: The Truth Untold (Romanizado)
# extracting song from: https://www.musica.com/letras.asp?letra=2174492
# Response from lyrics page: 200
# Title: Tomorrow
# extracting song from: https://www.musica.com/letras.asp?letra=2175381
# Response from lyrics page: 200
# Title: Tomorrow en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174592
# Response from lyrics page: 200
# Title: Tomorrow en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2402985
# Response from lyrics page: 200
# Title: Trivia 承: Love
# extracting song from: https://www.musica.com/letras.asp?letra=2403557
# Response from lyrics page: 200
# Title: Trivia: Seesaw
# extracting song from: https://www.musica.com/letras.asp?letra=2419980
# Response from lyrics page: 200
# Title: Waste It On Me
# extracting song from: https://www.musica.com/letras.asp?letra=2419981
# Response from lyrics page: 200
# Title: Waste It On Me en español
# extracting song from: https://www.musica.com/letras.asp?letra=2353944
# Response from lyrics page: 200
# Title: We Are Bulletprof Pt.1 en español
# extracting song from: https://www.musica.com/letras.asp?letra=2353941
# Response from lyrics page: 200
# Title: We Are Bulletprof Pt.1 en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2144343
# Response from lyrics page: 200
# Title: We Are Bulletproof
# extracting song from: https://www.musica.com/letras.asp?letra=2506687
# Response from lyrics page: 200
# Title: We Are Bulletproof : The Eternal
# extracting song from: https://www.musica.com/letras.asp?letra=2153672
# Response from lyrics page: 200
# Title: We are bulletproof part.2 en español
# extracting song from: https://www.musica.com/letras.asp?letra=2355502
# Response from lyrics page: 200
# Title: We Are Bulletproof Pt.1 - Rap Monster ,Iron & Supreme Boi
# extracting song from: https://www.musica.com/letras.asp?letra=2356868
# Response from lyrics page: 200
# Title: We Are Bulletproof Pt.1 - Rap Monster ,Iron & Supreme Boi en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174658
# Response from lyrics page: 200
# Title: We Are Bulletproof Pt.2 en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2510570
# Response from lyrics page: 200
# Title: We Are Bulletproof: The Eternal en español
# extracting song from: https://www.musica.com/letras.asp?letra=2152228
# Response from lyrics page: 200
# Title: We On
# extracting song from: https://www.musica.com/letras.asp?letra=2174569
# Response from lyrics page: 200
# Title: We On en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174659
# Response from lyrics page: 200
# Title: We On en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2291901
# Response from lyrics page: 200
# Title: Whalien 52
# extracting song from: https://www.musica.com/letras.asp?letra=2354357
# Response from lyrics page: 200
# Title: Whalien 52 en español
# extracting song from: https://www.musica.com/letras.asp?letra=2354358
# Response from lyrics page: 200
# Title: Whalien 52 en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2174488
# Response from lyrics page: 200
# Title: Where Did You Come From?
# extracting song from: https://www.musica.com/letras.asp?letra=2175380
# Response from lyrics page: 200
# Title: Where Did You Come From? en español
# extracting song from: https://www.musica.com/letras.asp?letra=2174594
# Response from lyrics page: 200
# Title: Where Did You Come From? en inglés
# extracting song from: https://www.musica.com/letras.asp?letra=2507839
# Response from lyrics page: 200
# Title: Who
# extracting song from: https://www.musica.com/letras.asp?letra=2574647
# Response from lyrics page: 200
# Title: 'Yet To Come (The Most Beautiful Moment)'
# extracting song from: https://www.musica.com/letras.asp?letra=2519572
# Response from lyrics page: 200
# Title: Your Eyes Tell
# extracting song from: https://www.musica.com/letras.asp?letra=2519574
# Response from lyrics page: 200
# Title: Your Eyes Tell en español
# extracting song from: https://www.musica.com/letras.asp?letra=2534896
# Response from lyrics page: 200
# Title: 내 방을 여행하는 법 (Fly To My Room)
# extracting song from: https://www.musica.com/letras.asp?letra=2449014
# Response from lyrics page: 200
# Title: 소우주 (Mikrokosmos)
# extracting song from: https://www.musica.com/letras.asp?letra=2506688
# Response from lyrics page: 200
# Title: 시차 (My Time)
# extracting song from: https://www.musica.com/letras.asp?letra=2506697
# Response from lyrics page: 200
# Title: 시차 (My Time) en español
# extracting song from: https://www.musica.com/letras.asp?letra=2506689
# Response from lyrics page: 200
# Title: 욱 (ugh!)
# extracting song from: https://www.musica.com/letras.asp?letra=2506695
# Response from lyrics page: 200
# Title: 욱 (ugh!) en español
# extracting song from: https://www.musica.com/letras.asp?letra=2449009
# Response from lyrics page: 200
# Title: 작은 것들을 위한 시 (Boy With Luv) ft. Halsey
# extracting song from: https://www.musica.com/letras.asp?letra=2402990
# Response from lyrics page: 200
# Title: 전하지 못한 진심 The Truth Untold
# extracting song from: https://www.musica.com/letras.asp?letra=2506690
# Response from lyrics page: 200
# Title: 친구 (Friend)
# 'BTS\n===\nTítulo: 離れないで (歌詞) \n\n 離れないで (歌詞)\n君の言葉にはいくつもの意味が\nあるように間こえるから   What’s what?\n謎の足跡見つけたら Follow\n飲み込まれる My Shadow 光の裏側に潜めた\n会えない君だけが知る My Answer\n途切れる前に I wanna know everything\n時が流れるほど深まる君の\n過去と未来の間にいる僕は今\nI Don’t Leave Me, now Believe 走り出す\nNo Ending 君は僕の鼓動\n例えどんな雨に打たれても 例えどんな闇に消されても\n救い出すよ必ず 君は一人じゃない\n動くはずなし時計の金ナが今 一歩一歩踏み出すように moving on\nCalling me passing me すれ違い all of it, destiny\nそれでも女台まる one way race 離れ初めても that’s okay\n「何も心配しないでよ いや、何も」\n\n===\n\nTítulo: 방탄소년단 Save Me \n\n 방탄소년단 Save Me\n[Jimin] Nan sumswigo sipeo I bami sireo\nIjen kkaego sipeo kkumsogi sireo\nNae ane gathyeoseo nan jugeoisseo\nDon’t wanna be lonely\nJust wanna be yours\n[JungKook] Wae iri kkamkkamhan geonji\nNiga eoptneun I goseun\nWiheomhajanha manggajin nae moseup\nGuhaejwo nal nado nal jabeul su eopseo (su eopseo)\n[V] Nae simjangsoril deureobwa\nJemeotdaero neol bureujanha\n[Jin] I kkaman eodum sogeseo\nNeoneun ireoke bitnanikka\n[V] Geu soneul naemireojwo Save me Save me\nI need your love before I fall fall\n[Jin] Geu soneul naemireojwo Save me Save me\nI need your love before I fall fall\n[JungKook] Geu soneul naemireojwo Save me Save me\n[Jimin] Geu soneul naemireojwo Save me Save me\n[JungKook] Save me save me\n[SUGA] Oneulttara dari bitna nae gieok sogui binkan\nNal samkyeobeorin I Lunatic\nPlease save me tonight\n(Please save me tonight\nPlease save me tonight)\nI chigi eorin gwanggi sok nareul guwonhaejul I bam\n[J-Hope] Nan aratji neoran guwoni\nNae salmui ilbumyeo apeumeul gamssajul yuilhan songil\nThe best of me nan neobakke eoptji\nNa dasi useul su itdorok deo nopyeojwo ni moksoril\nPlay On\n[JungKook] Nae simjangsoril deureobwa\nJemeotdaero neol bureujanha\n[Jimin] I kkaman eodum sogeseo\nNeoneun ireoke bitnanikka\n[V] Geu soneul naemireojwo Save me Save me\nI need your love before I fall fall\n[Jin] Geu soneul naemireojwo Save me Save me\nI need your love before I fall fall\n[JungKook] Geu soneul naemireojwo Save me Save me\n[Jimin] Geu soneul naemireojwo Save me Save me\n[Rap Monster] Gomawo naega naige haejwoseo\nI naega nalge haejwoseo\nIreon naege nalgael jwoseo\nKkogithadeon nal gae jwoseo\nDapdaphadeon nal kkaejwoseo\nKkum sogeman saldeon nal kkaewojwoseo\nNeol saenggakhamyeon nal gaeeoseo\nSeulpeum ttawin na gae jwosseo\n(Thank you uriga dwae jwoseo)\n[Jimin] Geu soneul naemireojwo Save me Save me\nI need your love before I fall fall\n[JungKook] Geu soneul naemireojwo Save me Save me\nI need your love before I fall fall\n\n===\n\nTítulo: 방탄소년단 Save Me en español \n\n 방탄소년단 Save Me\n[Jimin]\nQuiero respirar, odio esta noche\nQuiero despertar, odio este sueño\nEstoy atrapado dentro de mí mismo y estoy muerto\nNo quiero estar solo\nSólo quiero ser tuyo\n[JungKook]\n¿Por qué está tan oscuro en donde no estás?\nEs peligroso cuán estropeado estoy\nSálvame, porque no tengo control sobre mí mismo\n[V]\nEscucha el latido de mi corazón\nTe llama cada vez que quiere\n[Jin]\nPorque dentro de esta oscuridad\nTú brillas tan intensamente\nESTRIBILLO -\n[v]\nDame tu mano, sálvame, sálvame\nNecesito tu mano antes de que caiga, caiga\n[Jimin]\nDame tu mano, sálvame, sálvame\nNecesito tu mano antes de que caiga, caiga\n[JungKook]\nDame tu mano, sálvame, sálvame\nOh ,Oh ,salvame\n[Jimin]\nDame tu mano, sálvame, sálvame\nOh ,Oh ,sálvame\nSálvame ,sálvame -\n[Suga]\nHoy la luna brilla más brillante en los lugares vacíos de mis recuerdos\nMe traga, este loco, por favor, sálvame esta noche\n(Por favor, dame esta noche,\npor favor, sálvame esta noche)\nDentro de esta locura infantil\ntú me salvarás esta noche\n[J-Hope]\nSabía que tu salvación\nUna parte de mi vida y\nLa única mano que abrazará mi dolor\nLa mejor de mí, tú eres lo único que tengo\nPor favor, alza tu voz, así puedo reír otra vez\n[JungKook]\nEscucha el latido de mi corazón\nTe llama cada vez que quiere\n[Jimin]\nPorque dentro de esta oscuridad\nTú brillas tan intensamente\nESTRIBILLO -\n[v]\nDame tu mano, sálvame, sálvame\nNecesito tu mano antes de que caiga, caiga\n[Jimin] ...

# %%
from dotenv import load_dotenv
import openai
import os
from llama_index.core import (
    VectorStoreIndex, 
    SimpleDirectoryReader, 
    StorageContext,
    load_index_from_storage,
    Document,
    PromptTemplate
)
load_dotenv()
# Out:
# True

# %%
def get_artist_documents(filename: str) -> list[Document]:
    with open(filename) as file:
        data = file.read()
    songs = data.split("===")
    artist = songs.pop(0).strip()
    
    documents = [
        Document(
            text=song,
            metadata={
                "category":"music",
                "artist": artist,
            }
        )
        for song in songs
    ]    
    return documents

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings

embed_model = HuggingFaceEmbedding(model_name="intfloat/multilingual-e5-base")
Settings.embed_model = embed_model
# Out:
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# c:\Users\Ambar\anaconda3\envs\topics_2024\Lib\site-packages\huggingface_hub\file_download.py:147: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Ambar\AppData\Local\llama_index\models--intfloat--multilingual-e5-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# README.md:   0%|          | 0.00/179k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]

# %%
PERSIST_DIR = "lyrics_store2"

if not os.path.exists(PERSIST_DIR):
    documents = get_artist_documents("47923_BTS.txt")
    index = VectorStoreIndex.from_documents(documents, show_progress=True)
    index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR) 
    index = load_index_from_storage(storage_context)
# Out:
# Parsing nodes:   0%|          | 0/314 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/327 [00:00<?, ?it/s]

# %%
query_engine = index.as_query_engine(verbose=True)

# %%
qa_template_str = """
    You are an expert in K-Pop music, your task is to guide and teach the user 
    about your field. Answer the user queries only with supported data in your context.
    Your context may contain complete lyrics or parts of them in different languages, but
    your answer will always be in Spanish. 

    Context information is below.
    ---------------------
    {context_str}
    ---------------------
    Given the context information and not prior knowledge, 
    answer the query with detailed source information, include direct quotes and use bullet lists in your 
    answers, in one of the bullets detail the tone/sentiment of the song.
    Query: {query_str}
    Answer: 
"""
qa_template = PromptTemplate(qa_template_str)

# %%
query_engine.update_prompts(
    {"response_synthesizer:text_qa_template": qa_template}
)

# %%
response = query_engine.query("cuales canciones de BTS hablan de amor?")

# %%
print(response)
# Out:
# - La canción "Fake Love" de BTS habla sobre el amor, específicamente sobre un amor falso y las emociones contradictorias que puede generar. Algunas partes de la letra que reflejan esto son:
#   - "Estoy tan harto de este falso amor, falso amor, falso amor"
#   - "Intento moldear una mentira bonita para ti"
#   - "El amor es una locura, el amor es una locura"
#   - Tonos/sentimientos de la canción: melancólico, decepcionado, confundido.
#
# - Otra canción de BTS que habla sobre el amor es "Waste It On Me". Aunque la canción aborda más la idea de si el amor es una pérdida de tiempo, también refleja la temática del amor. Algunas partes de la letra que lo muestran son:
#   - "So if love is nothing more, then just a waste of your time?"
#   - "Waste it on me, waste it on me"
#   - Tonos/sentimientos de la canción: reflexivo, cuestionador, esperanzador.

# %%
response.source_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='845bf103-f759-4b71-900d-ce53120ef34d', embedding=None, metadata={'category': 'music', 'artist': 'BTS'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e46d213a-9ef6-463a-9fd1-5b3dd0b4183b', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'category': 'music', 'artist': 'BTS'}, hash='0577ae1459c28fbdbb436c27328128a77245662562c141c9fb938fdf55c3f293')}, text="Título: Fake Love en español \n\n Fake Love\n[Intro: V, Jungkook]\nPor ti, podía fingir que estaba feliz cuando estaba triste\nPor ti, podía fingir que era fuerte cuando estaba herido\nDesearía que el amor fuera perfecto como el amor mismo\nDesearía que todas mis debilidades pudieran ser ocultadas\nCuidé de una flor que no puede florecer en un sueño que no puede volverse realidad\n[Hook: Jimin]\nEstoy tan harto de este falso amor, falso amor, falso amor\nLo siento mucho pero es falso amor, falso amor, falso amor\n[Verse 1: RM, Jungkook, J-Hope]\nQuiero ser un buen hombre solo por ti\nTe di el mundo\nCambié todo solo por ti\nPero me conozco, ¿quién eres tú?\nEl bosque solo para nosotros, no estuviste ahí\nLa ruta que tomé, la olvidé\nIncluso me sentí inseguro de quien yo era\nInrento balbucear en el espejo, ¿quién diablos eres tú?\n[Pre-Chorus: Jimin, Jungkook, Jin]\n[Chorus: Jungkook, V]\nTe amo tanto, te amo tanto\nIntento moldear una mentira bonita para ti\nEl amor es una locura, el amor es una locura\nTrato de borrarme y hacerme tu muñeca\nTe amo tanto, te amo tanto\nTe amo tanto, te amo tanto\nIntento moldear una mentira bonita para ti\nEl amor es una locura, el amor es una locura\nTrato de borrarme y hacerme tu muñeca\n[Hook: Jimin]\nEstoy tan harto de este\nFalso amor, falso amor, falso amor\nLo siento pero es\nFalso amor, falso amor, falso amor\n[Verse 2: RM, Suga]\nY you sad? I don’t know. I don’t know\nSmile, say ‘I love you’\nLook at me, even I gave up on myself\n¿Por qué estás tan triste? No lo sé, no lo sé\nSonríe, dime 'te amo'\nMírame, incluso renuncié a mí\nNi siquiera puedes entenderme\nDices que estoy irreconocible, cambié a quien solía gustarte\nDices que no soy el mismo al que conocías bien\n¿No? ¿A qué te refieres? Estoy ciego\n¿Amor? ¿Qué diablos es amor? Todo es falso amor\n[Bridge: Jungkook, Jin]\nWoo, no sé, no sé, no sé por qué\nWoo, ni siquiera, ni siquiera yo me conozco\nWoo, solo sé, sé, sé por qué\nPorque es todo falso amor, falso amor, falso amor\n[Chorus: Jungkook, Jimin]\n[Chorus: Jungkook, Jimin]\n[Outro: Jimin/V, Jungkook/Jin]\nPor ti, podía fingir que estaba feliz cuando estaba triste\nPor ti, podía fingir que era fuerte cuando estaba herido\nDesearía que el amor fuera perfecto como el amor mismo\nDesearía que todas mis debilidades pudieran ser ocultadas\nCuidé de una flor que no puede florecer en un sueño que no puede volverse realidad", mimetype='text/plain', start_char_idx=2, end_char_idx=2354, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.8455295127122996),
#  NodeWithScore(node=TextNode(id_='49691f67-81ff-4004-ac71-20233044cf64', embedding=None, metadata={'category': 'music', 'artist': 'BTS'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1d9d380c-6f52-4ce4-bb86-da75a7c464ed', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'category': 'music', 'artist': 'BTS'}, hash='6909aaad1ca819308a213297e6f0124d04cf0ec353f9800f52215829d2324f0e')}, text='Título: Waste It On Me \n\n Waste It On Me\n[Pre-Chorus]\nAnd I know there’s no making this right, this right\nAnd I know there’s no changing your mind, your mind\nBut we both found each other tonight, tonight\nSo if love is nothing more\nThen just a waste of your time?\n[Chorus]\nWaste it on me\nWaste it on me\n(waste it on me)\nTell me why not\nWaste it on me\nWaste it on me\n(waste it on me)\nBaby why not\nWaste it on me\nWaste it on me\n(waste it on me)\nTell me why not\nWaste it on me\nWaste it on me\n(waste it on me)', mimetype='text/plain', start_char_idx=2, end_char_idx=506, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.8447540477726113)]

# %%
chat_engine = index.as_chat_engine(verbose=True)

# %%
response = chat_engine.chat("que canciones de BTS hablan de amor?")
# Out:
# Added user message to memory: que canciones de BTS hablan de amor?
# === Calling Function ===
# Calling function: query_engine_tool with args: {"input":"Canciones de BTS que hablan de amor"}
# Got output: Fake Love, Waste It On Me
# ========================

# %%
print(response)
# Out:
# Algunas canciones de BTS que hablan de amor son "Fake Love" y "Waste It On Me".

# %%
print(chat_engine.chat("y cuales hablan de amor propio?"))
# Out:
# Added user message to memory: y cuales hablan de amor propio?
# === Calling Function ===
# Calling function: query_engine_tool with args: {"input":"Canciones de BTS que hablan de amor propio"}
# Got output: Singularity
# ========================
#
# Una canción de BTS que habla de amor propio es "Singularity".
